# %%
# 1D CNN Model Notebook

import numpy as np
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt

# %%
# Load preprocessed data
X_train = np.load('X_train.npy')
y_train = np.load('y_train.npy')
X_test = np.load('X_test.npy')
y_test = np.load('y_test.npy')

# %%
# Build 1D CNN model
model = Sequential([
    Conv1D(filters=64, kernel_size=3, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])),
    MaxPooling1D(pool_size=2),
    Conv1D(filters=32, kernel_size=3, activation='relu'),
    MaxPooling1D(pool_size=2),
    Flatten(),
    Dense(50, activation='relu'),
    Dropout(0.2),
    Dense(y_train.shape[1])
])

model.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 8, 64)             1024
#
#  max_pooling1d (MaxPooling1  (None, 4, 64)             0
#  D)
#
#  conv1d_1 (Conv1D)           (None, 2, 32)             6176
#
#  max_pooling1d_1 (MaxPoolin  (None, 1, 32)             0
#  g1D)
#
#  flatten (Flatten)           (None, 32)                0
#
#  dense (Dense)               (None, 50)                1650
#
#  dropout (Dropout)           (None, 50)                0
#
#  dense_1 (Dense)             (None, 5)                 255
#
# =================================================================
# Total params: 9105 (35.57 KB)
# Trainable params: 9105 (35.57 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/100
# 184/184 [==============================] - 3s 5ms/step - loss: 0.0069 - val_loss: 0.0023
# Epoch 2/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0034 - val_loss: 0.0021
# Epoch 3/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0031 - val_loss: 0.0024
# Epoch 4/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0028 - val_loss: 0.0020
# Epoch 5/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0027 - val_loss: 0.0020
# Epoch 6/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0025 - val_loss: 0.0022
# Epoch 7/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0025 - val_loss: 0.0019
# Epoch 8/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0023 - val_loss: 0.0020
# Epoch 9/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0023 - val_loss: 0.0018
# Epoch 10/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 11/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 12/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 13/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 14/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 15/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0021 - val_loss: 0.0018
# Epoch 16/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 17/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0021 - val_loss: 0.0019
# Epoch 18/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 19/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 20/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 21/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 22/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 23/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 24/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 25/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 26/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 27/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 28/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 29/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0020
# Epoch 30/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 31/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 32/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0020 - val_loss: 0.0018
# Epoch 33/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 34/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 35/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0020 - val_loss: 0.0019
# Epoch 36/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 37/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 38/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 39/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 40/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 41/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 42/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 43/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 44/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 45/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 46/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 47/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 48/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 49/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 50/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 51/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 52/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 53/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 54/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 55/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 56/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 57/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 58/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 59/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 60/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 61/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 62/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 63/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 64/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 65/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 66/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 67/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 68/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 69/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 70/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 71/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 72/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 73/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 74/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 75/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 76/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 77/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 78/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0018
# Epoch 79/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 80/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 81/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 82/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 83/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 84/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 85/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0021
# Epoch 86/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 87/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 88/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 89/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 90/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 91/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 92/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 93/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 94/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 95/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 96/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 97/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0019
# Epoch 98/100
# 184/184 [==============================] - 1s 3ms/step - loss: 0.0018 - val_loss: 0.0018
# Epoch 99/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0020
# Epoch 100/100
# 184/184 [==============================] - 1s 4ms/step - loss: 0.0018 - val_loss: 0.0018

# %%
# Evaluate the model
y_pred = model.predict(X_test)

mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"Mean Absolute Error: {mae}")
print(f"R-squared Score: {r2}")
# Out:
# 58/58 [==============================] - 0s 3ms/step
# Mean Squared Error: 0.001076974729600427
# Mean Absolute Error: 0.01592780200633523
# R-squared Score: 0.8118042447226097

# %%
# Plot training history
plt.figure(figsize=(12, 6))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('1D CNN Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# Plot predictions vs actual
plt.figure(figsize=(12, 6))
plt.plot(y_test[:, 0], label='Actual')
plt.plot(y_pred[:, 0], label='Predicted')
plt.title('1D CNN: Actual vs Predicted Closing Prices')
plt.xlabel('Time')
plt.ylabel('Normalized Closing Price')
plt.legend()
plt.show()

# %%
# Additional Evaluation Metrics

import numpy as np
from sklearn.metrics import confusion_matrix, f1_score
import seaborn as sns
import matplotlib.pyplot as plt

def calculate_additional_metrics(y_true, y_pred):
    # Calculate price movement direction
    y_true_direction = np.diff(y_true[:, 0]) > 0
    y_pred_direction = np.diff(y_pred[:, 0]) > 0

    # Compute confusion matrix
    cm = confusion_matrix(y_true_direction, y_pred_direction)

    # Compute F1 score
    f1 = f1_score(y_true_direction, y_pred_direction)

    return cm, f1

def plot_confusion_matrix(cm, title):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title(f'{title} - Confusion Matrix')
    plt.ylabel('True Direction')
    plt.xlabel('Predicted Direction')
    plt.show()

# Calculate additional metrics
cm, f1 = calculate_additional_metrics(y_test, y_pred)

# Print F1 score
print(f"F1 Score: {f1:.4f}")

# Plot confusion matrix
plot_confusion_matrix(cm, model.__class__.__name__)

# Interpret confusion matrix
tn, fp, fn, tp = cm.ravel()
total = tn + fp + fn + tp
accuracy = (tn + tp) / total
print(f"Accuracy: {accuracy:.4f}")
print(f"True Positive Rate (Sensitivity): {tp / (tp + fn):.4f}")
print(f"True Negative Rate (Specificity): {tn / (tn + fp):.4f}")
print(f"Positive Predictive Value (Precision): {tp / (tp + fp):.4f}")
print(f"Negative Predictive Value: {tn / (tn + fn):.4f}")
# Out:
# F1 Score: 0.5094
# Accuracy: 0.5044
# True Positive Rate (Sensitivity): 0.5262
# True Negative Rate (Specificity): 0.4835
# Positive Predictive Value (Precision): 0.4937
# Negative Predictive Value: 0.5159

# %%
import numpy as np
from sklearn.metrics import accuracy_score, f1_score, mean_squared_error, mean_absolute_error, r2_score
import matplotlib.pyplot as plt
import seaborn as sns

def calculate_direction_metrics(y_true, y_pred, threshold=0):
    """
    Calculate accuracy and F-score based on the direction of price movement.
    
    :param y_true: True closing prices
    :param y_pred: Predicted closing prices
    :param threshold: Minimum change to be considered as a movement (default: 0)
    :return: Dictionary containing accuracy and F-score
    """
    # Calculate price movement direction
    y_true_direction = np.diff(y_true[:, 0]) > threshold
    y_pred_direction = np.diff(y_pred[:, 0]) > threshold
    
    # Compute accuracy and F-score
    accuracy = accuracy_score(y_true_direction, y_pred_direction)
    f1 = f1_score(y_true_direction, y_pred_direction)
    
    return {
        'accuracy': accuracy,
        'f1_score': f1
    }

def evaluate_regression_model(y_true, y_pred):
    """
    Evaluate regression model using various metrics.
    
    :param y_true: True closing prices
    :param y_pred: Predicted closing prices
    :return: Dictionary containing evaluation metrics
    """
    mse = mean_squared_error(y_true, y_pred)
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    
    direction_metrics = calculate_direction_metrics(y_true, y_pred)
    
    return {
        'mse': mse,
        'mae': mae,
        'r2_score': r2,
        'accuracy': direction_metrics['accuracy'],
        'f1_score': direction_metrics['f1_score']
    }

def plot_predictions(y_true, y_pred, title):
    """
    Plot true vs predicted values.
    
    :param y_true: True closing prices
    :param y_pred: Predicted closing prices
    :param title: Title of the plot
    """
    plt.figure(figsize=(12, 6))
    plt.plot(y_true[:, 0], label='Actual')
    plt.plot(y_pred[:, 0], label='Predicted')
    plt.title(f'{title}: Actual vs Predicted Closing Prices')
    plt.xlabel('Time')
    plt.ylabel('Normalized Closing Price')
    plt.legend()
    plt.show()

def plot_error_distribution(y_true, y_pred, title):
    """
    Plot the distribution of prediction errors.
    
    :param y_true: True closing prices
    :param y_pred: Predicted closing prices
    :param title: Title of the plot
    """
    errors = y_true[:, 0] - y_pred[:, 0]
    plt.figure(figsize=(10, 6))
    sns.histplot(errors, kde=True)
    plt.title(f'{title}: Distribution of Prediction Errors')
    plt.xlabel('Error')
    plt.ylabel('Frequency')
    plt.show()

# Example usage (add this to each model notebook after making predictions):
metrics = evaluate_regression_model(y_test, y_pred)
print("Evaluation Metrics:")
for metric, value in metrics.items():
    print(f"{metric}: {value:.4f}")

plot_predictions(y_test, y_pred, model.__class__.__name__)
plot_error_distribution(y_test, y_pred, model.__class__.__name__)
# Out:
# Evaluation Metrics:
# mse: 0.0011
# mae: 0.0159
# r2_score: 0.8118
# accuracy: 0.5044
# f1_score: 0.5094
